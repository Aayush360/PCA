# %%
# import liararies

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
# load the dataset

df = pd.read_excel('2021-average-values-2.xlsx')
df.head()
# Out:
#   File Name  Median Number of Roots  Maximum Number of Roots  \
# 0       E-1                1.333333                 7.666667
# 1       E-2                1.666667                 8.666667
# 2       e-5                3.000000                13.500000
# 3       E-7                3.000000                11.666667
# 4       E-8                2.000000                 9.666667
#
#    Number of Root Tips  Total Root Length        Depth  Maximum Width  \
# 0            72.000000        6027.346667  1942.666667     642.333333
# 1            89.666667        6124.556667  1498.666667     413.333333
# 2           156.500000       10633.905000  1523.000000     866.500000
# 3           197.666667       15029.363330  2025.000000    1035.666667
# 4            65.000000        7596.116667  1540.000000    1108.000000
#
#    Width-to-Depth Ratio  Network Area   Convex Area  ...  Average Hole Size  \
# 0              0.337494   114327.6667  6.081240e+05  ...        1061.477667
# 1              0.271225   107012.3333  4.023363e+05  ...         813.093333
# 2              0.564773   110906.5000  8.282115e+05  ...        2237.943000
# 3              0.544554   168416.3333  1.075985e+06  ...         765.552333
# 4              0.710880   120945.6667  9.596013e+05  ...        2421.893667
#
#    Computation Time  Average Root Orientation  Shallow Angle Frequency  \
# 0          0.149667                 58.222633                 0.184488
# 1          0.120333                 57.090933                 0.235690
# 2          0.162500                 53.098600                 0.241076
# 3          0.212667                 55.718767                 0.201371
# 4          0.181000                 54.126167                 0.215357
#
#    Medium Angle Frequency  Steep Angle Frequency  Fine Diameter Frequency  \
# 0                0.236488               0.579024                 0.118654
# 1                0.182359               0.581951                 0.140089
# 2                0.293106               0.465817                 0.197978
# 3                0.264966               0.533662                 0.188319
# 4                0.301807               0.482837                 0.107015
#
#    Medium Diameter Frequency  Coarse Diameter Frequency  Unnamed: 28
# 0                   0.274584                   0.606762          NaN
# 1                   0.300210                   0.559701          NaN
# 2                   0.325394                   0.476629          NaN
# 3                   0.259664                   0.552017          NaN
# 4                   0.311955                   0.581030          NaN
#
# [5 rows x 29 columns]

# %%
df.shape
# Out:
# (185, 29)

# %%
df.describe()
# Out:
#        Median Number of Roots  Maximum Number of Roots  Number of Root Tips  \
# count              185.000000               185.000000           185.000000
# mean                 2.399099                11.525225           141.820721
# std                  1.102820                 4.528189            90.233658
# min                  1.000000                 3.500000            23.500000
# 25%                  1.500000                 8.000000            65.000000
# 50%                  2.333333                11.000000           125.000000
# 75%                  3.000000                14.666667           193.666667
# max                  6.666667                26.666667           436.666667
#
#        Total Root Length        Depth  Maximum Width  Width-to-Depth Ratio  \
# count         185.000000   185.000000     185.000000            185.000000
# mean        11933.247477  1753.645946     814.520721              0.478679
# std          7155.497424   408.193505     242.718335              0.129858
# min          2281.330000   780.500000     294.500000              0.242168
# 25%          6075.723333  1513.000000     654.500000              0.386191
# 50%         10633.905000  1760.500000     811.666667              0.449495
# 75%         15969.183330  2056.000000     980.000000              0.569636
# max         41320.866670  2544.000000    1631.000000              0.957264
#
#         Network Area   Convex Area    Solidity  ...  Average Hole Size  \
# count     185.000000  1.850000e+02  185.000000  ...         185.000000
# mean   167571.514415  8.864781e+05    0.224655  ...        1622.862367
# std     65380.137007  4.006989e+05    0.079528  ...        1538.397288
# min     63473.333330  1.662795e+05    0.099182  ...          55.400000
# 25%    120945.666700  5.891710e+05    0.169337  ...         758.909000
# 50%    155233.333300  8.450835e+05    0.207391  ...        1107.733000
# 75%    205402.000000  1.191514e+06    0.255786  ...        1933.233333
# max    435357.333300  2.120000e+06    0.536590  ...       11418.500000
#
#        Computation Time  Average Root Orientation  Shallow Angle Frequency  \
# count        185.000000                185.000000               185.000000
# mean           0.199382                 54.029838                 0.230688
# std            0.054840                  4.047666                 0.045298
# min            0.105000                 32.820667                 0.125164
# 25%            0.157000                 51.764833                 0.200044
# 50%            0.199000                 54.266033                 0.227105
# 75%            0.237667                 56.446267                 0.256261
# max            0.407667                 64.810000                 0.397963
#
#        Medium Angle Frequency  Steep Angle Frequency  Fine Diameter Frequency  \
# count              185.000000             185.000000               185.000000
# mean                 0.263570               0.503941                 0.121137
# std                  0.041083               0.071346                 0.051397
# min                  0.158050               0.276917                 0.019757
# 25%                  0.238538               0.462944                 0.076892
# 50%                  0.261708               0.505087                 0.121975
# 75%                  0.289644               0.544209                 0.159690
# max                  0.430041               0.693528                 0.242243
#
#        Medium Diameter Frequency  Coarse Diameter Frequency  Unnamed: 28
# count                 185.000000                 185.000000          1.0
# mean                    0.262031                   0.615030          0.0
# std                     0.061943                   0.106588          NaN
# min                     0.071812                   0.414036          0.0
# 25%                     0.226631                   0.522134          0.0
# 50%                     0.266893                   0.607881          0.0
# 75%                     0.311955                   0.687508          0.0
# max                     0.383006                   0.897199          0.0
#
# [8 rows x 28 columns]

# %%
df.isnull().sum()
# Out:
# File Name                      0
# Median Number of Roots         0
# Maximum Number of Roots        0
# Number of Root Tips            0
# Total Root Length              0
# Depth                          0
# Maximum Width                  0
# Width-to-Depth Ratio           0
# Network Area                   0
# Convex Area                    0
# Solidity                       0
# Lower Root Area                0
# Average Diameter               0
# Median Diameter                0
# Maximum Diameter               0
# Perimeter                      0
# Volume                         0
# Surface Area                   0
# Holes                          0
# Average Hole Size              0
# Computation Time               0
# Average Root Orientation       0
# Shallow Angle Frequency        0
# Medium Angle Frequency         0
# Steep Angle Frequency          0
# Fine Diameter Frequency        0
# Medium Diameter Frequency      0
# Coarse Diameter Frequency      0
# Unnamed: 28                  184
# dtype: int64

# %%
df_clean=df.drop('Unnamed: 28',axis=1)

# %%
df_clean.head()
# Out:
#   File Name  Median Number of Roots  Maximum Number of Roots  \
# 0       E-1                1.333333                 7.666667
# 1       E-2                1.666667                 8.666667
# 2       e-5                3.000000                13.500000
# 3       E-7                3.000000                11.666667
# 4       E-8                2.000000                 9.666667
#
#    Number of Root Tips  Total Root Length        Depth  Maximum Width  \
# 0            72.000000        6027.346667  1942.666667     642.333333
# 1            89.666667        6124.556667  1498.666667     413.333333
# 2           156.500000       10633.905000  1523.000000     866.500000
# 3           197.666667       15029.363330  2025.000000    1035.666667
# 4            65.000000        7596.116667  1540.000000    1108.000000
#
#    Width-to-Depth Ratio  Network Area   Convex Area  ...      Holes  \
# 0              0.337494   114327.6667  6.081240e+05  ...  15.666667
# 1              0.271225   107012.3333  4.023363e+05  ...  21.666667
# 2              0.564773   110906.5000  8.282115e+05  ...  72.000000
# 3              0.544554   168416.3333  1.075985e+06  ...  93.666667
# 4              0.710880   120945.6667  9.596013e+05  ...  16.333333
#
#    Average Hole Size  Computation Time  Average Root Orientation  \
# 0        1061.477667          0.149667                 58.222633
# 1         813.093333          0.120333                 57.090933
# 2        2237.943000          0.162500                 53.098600
# 3         765.552333          0.212667                 55.718767
# 4        2421.893667          0.181000                 54.126167
#
#    Shallow Angle Frequency  Medium Angle Frequency  Steep Angle Frequency  \
# 0                 0.184488                0.236488               0.579024
# 1                 0.235690                0.182359               0.581951
# 2                 0.241076                0.293106               0.465817
# 3                 0.201371                0.264966               0.533662
# 4                 0.215357                0.301807               0.482837
#
#    Fine Diameter Frequency  Medium Diameter Frequency  \
# 0                 0.118654                   0.274584
# 1                 0.140089                   0.300210
# 2                 0.197978                   0.325394
# 3                 0.188319                   0.259664
# 4                 0.107015                   0.311955
#
#    Coarse Diameter Frequency
# 0                   0.606762
# 1                   0.559701
# 2                   0.476629
# 3                   0.552017
# 4                   0.581030
#
# [5 rows x 28 columns]

# %%
corr=df_clean.corr()

# %%
plt.figure(figsize=(14,12))

sns.heatmap(corr,cmap='RdYlGn',linewidths=0.30,annot=True)
plt.title('heatmap showing correlation of features')
plt.show()

# %%
# separating the features

# %%
#features = ['Median Number of Roots','Maximum Number of Roots','Number of Root Tips','Total Root Length','Depth',
#           'Maximum Width','Width-to-Depth Ratio','Network Area','Convex Area','Solidity','Average Diameter','Coarse Diameter Frequency',
#          'Shallow Angle Frequency']

# %%
features = ['Median Number of Roots','Width-to-Depth Ratio','Network Area','Convex Area','Solidity','Average Diameter','Coarse Diameter Frequency',
           'Shallow Angle Frequency','Surface Area','Median Diameter']

# %%
# Separating out the features
x = df_clean.loc[:, features].values

# %%
# Standardizing the features
x = StandardScaler().fit_transform(x)

# %%
np.mean(x),np.std(x) # mean is near 0 and std dev is 1 after standarizing
# Out:
# (3.7447522560329604e-17, 1.0)

# %%
pca = PCA(n_components=2)

# %%
principalComponents = pca.fit_transform(x)

# %%
principal_df = pd.DataFrame(data = principalComponents
             , columns = ['pc1', 'pc2'])

# %%
principal_df.head()
# Out:
#         pc1       pc2
# 0  0.728773 -1.964441
# 1  1.822482 -0.966458
# 2 -1.084472 -1.651386
# 3 -1.579922 -0.871088
# 4 -0.560357 -1.403790

# %%
print('Explained variation per principal component: {}'.format(pca.explained_variance_ratio_))
# Out:
# Explained variation per principal component: [0.49743412 0.22557475]

# %%
per_var=pca.explained_variance_ratio_

# %%
plt.scatter(principal_df.pc1,principal_df.pc2,color = 'hotpink')
plt.title('PCA graph')
plt.xlabel('PC1 -{0:.2f}%'.format(per_var[0]))
plt.ylabel('PC2 -{0:.2f}%'.format(per_var[1]))


plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
pca = PCA(n_components=3)
principalComponents = pca.fit_transform(x)
principal_df = pd.DataFrame(data = principalComponents
             , columns = ['pc1', 'pc2','pc3'])

# %%
principal_df.head()
# Out:
#         pc1       pc2       pc3
# 0  0.728773 -1.964441 -0.825712
# 1  1.822482 -0.966458 -1.277186
# 2 -1.084472 -1.651386  1.156849
# 3 -1.579922 -0.871088  0.364016
# 4 -0.560357 -1.403790  1.928739

# %%
print('Explained variation per principal component: {}'.format(pca.explained_variance_ratio_))
# Out:
# Explained variation per principal component: [0.49743412 0.22557475 0.12660346]

# %%
per_var=pca.explained_variance_ratio_

# %%
fig = plt.figure()
ax = Axes3D(fig)

ax.scatter(principal_df.pc1, principal_df.pc2, principal_df.pc3)



ax.set_xlabel('PC1 -{0:.2f}%'.format(per_var[0]))
ax.set_ylabel('PC2 -{0:.2f}%'.format(per_var[1]))
ax.set_zlabel('PC3 -{0:.2f}%'.format(per_var[2]))

plt.show()
