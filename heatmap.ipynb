# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="white")
# %matplotlib inline

# %%
df = pd.read_excel('2020 Ionomics and RSA Features.xlsx')
df.head()
# Out:
#                Median Number of Roots  Maximum Number of Roots  \
# 0   160_271_2                1.666667                 8.666667
# 1  160_271_11                3.000000                16.333333
# 2  160_271_13                3.000000                14.000000
# 3  160_271_17                1.333333                10.333333
# 4  160_271_19                2.333333                12.000000
#
#    Number of Root Tips  Total Root Length        Depth  Maximum Width  \
# 0            89.666667        6124.556667  1498.666667     413.333333
# 1           213.666667       14978.976670  1663.333333    1198.666667
# 2           145.000000       14380.933330  2057.333333     837.666667
# 3            59.666667        6767.950000  1572.666667     811.666667
# 4            94.333333       11583.276670  2194.000000    1100.333333
#
#    Width-to-Depth Ratio  Network Area   Convex Area  ...  Manganese    Cobalt  \
# 0              0.271225   107012.3333  4.023363e+05  ...   0.054699  0.142215
# ...

# %%
df.shape
# Out:
# (50, 47)

# %%
#check for null values

df.isna().sum()
# Out:
#                              0
# Median Number of Roots       0
# Maximum Number of Roots      0
# Number of Root Tips          0
# Total Root Length            0
# Depth                        0
# Maximum Width                0
# Width-to-Depth Ratio         0
# Network Area                 0
# Convex Area                  0
# Solidity                     0
# Lower Root Area              0
# Average Diameter             0
# Median Diameter              0
# Maximum Diameter             0
# Perimeter                    0
# Volume                       0
# Surface Area                 0
# Holes                        0
# Average Hole Size            0
# Computation Time             0
# Average Root Orientation     0
# Shallow Angle Frequency      0
# Medium Angle Frequency       0
# Steep Angle Frequency        0
# Fine Diameter Frequency      0
# Medium Diameter Frequency    0
# Coarse Diameter Frequency    0
# Boron                        0
# Sodium                       0
# ...

# %%
corr = df.corr()

# %%
# upper triangular mask

mask = np.triu(np.ones_like(corr, dtype=bool))
fig, ax = plt.subplots(figsize=(12, 10))
cmap = sns.diverging_palette(230, 20, as_cmap=True)

sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot:>

# %%
ions=['Boron','Sodium','Magnesium','Aluminum','Phosphorus','Sulfur','Potassium','Calcium','Iron','Manganese','Cobalt','Nickle',                      
'Copper','Zinc','Arsenic','Rubidium','Strontium','Molybdenum','Cadmium']

# %%
root_features=['Median Number of Roots','Maximum Number of Roots','Number of Root Tips','Total Root Length','Depth','Maximum Width',
'Width-to-Depth Ratio','Ne,twork Area','Convex Area','Sol,idity','Lower Root Area','Average Diameter','Median Diameter',
'Maximum Diameter','Perimeter','Volume','Surface Area','Holes','Average Hole Size','Computation Time','Average Root Orientation',
'Shallow Angle Frequency','Medium Angle Frequency','Steep Angle Frequency','Fine Diameter Frequency','Medium Diameter Frequency',
'Coarse Diameter Frequency']

# %%
# ax = sns.heatmap(df[ions],
#                  cmap='YlGnBu',
#                  yticklabels=[ions],
#                  xticklabels=[root_features],
#                  cbar_kws={"orientation": "horizontal"})
# ax.set_aspect("equal")

# %%
# df[ions]
